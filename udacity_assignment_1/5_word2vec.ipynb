# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
words[:12]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
len(data), len(count), len(dictionary), len(reverse_dictionary)
# Out:
# (17005207, 50000, 50000, 50000)

# %%
count[:10]
# Out:
# [['UNK', 418391],
#  ('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201),
#  ('a', 325873),
#  ('to', 316376),
#  ('zero', 264975),
#  ('nine', 250430)]

# %%
data[:10]
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'a', 'term', 'of', 'term', 'as', 'originated']

# %%
len(batch), labels.shape
# Out:
# (8, (8, 1))

# %%
batch
# Out:
# array([12, 12, 12, 12,  6,  6,  6,  6], dtype=int32)

# %%
labels
# Out:
# array([[3084],
#        [5239],
#        [   6],
#        [ 195],
#        [   2],
#        [ 195],
#        [  12],
#        [3084]], dtype=int32)

# %%
vocabulary_size
# Out:
# 50000

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.209268
# Nearest to may: assistive, beauregard, larson, escalation, motto, caracalla, solemnly, starches,
# Nearest to been: mites, centralizing, irreplaceable, gateways, interconnection, mover, forward, occultist,
# Nearest to at: candida, diablo, scotland, feat, blanking, newsreel, oppression, settled,
# Nearest to a: pendergast, diversions, dispatches, favourites, turtledove, pa, moist, signalled,
# Nearest to first: counternarcotics, definitive, intergovernmentalism, doses, aquilonia, silky, perpetuated, moli,
# Nearest to when: moreover, sites, fond, catalans, tincture, ningen, deviant, inflate,
# Nearest to about: assessment, cossiga, mundar, amherst, nursia, rendezvous, plutonic, osage,
# Nearest to th: ritter, gj, guadalcanal, award, pastor, consumers, value, center,
# Nearest to most: palestine, explainable, staunchly, cleve, diana, chef, ethicists, magie,
# Nearest to six: broom, screenplays, obituaries, optical, dying, romagna, midfielders, monoids,
# Nearest to united: biophysics, touches, figs, lagoon, mutualism, certain, imperialist, porridge,
# Nearest to during: skill, mouthwash, brim, sing, accomplishments, tem, guildhall, prinz,
# Nearest to would: valera, cavity, posterior, endpin, turkic, excerpts, meuse, luxurious,
# Nearest to it: galician, tedious, kyo, distortions, brittle, pathologist, sg, lindsey,
# Nearest to that: sst, collectivism, quizzes, misconceptions, rancho, corporations, portsmouth, fiore,
# Nearest to or: harun, urea, playstation, proves, hurrian, ultimately, pseudorandom, sufficiently,
# Average loss at step 2000: 4.368496
# Average loss at step 4000: 3.867488
# Average loss at step 6000: 3.787916
# Average loss at step 8000: 3.689876
# Average loss at step 10000: 3.613897
# Nearest to may: must, can, would, should, will, grounds, assistive, solemnly,
# Nearest to been: by, be, was, typically, gateways, centralizing, madeira, setting,
# Nearest to at: in, on, mooted, pontic, scotland, supervisors, additionally, by,
# Nearest to a: the, this, granddaughter, denominational, turtledove, activism, its, pushes,
# Nearest to first: same, definitive, only, caustic, refinement, earth, wiener, jacinto,
# Nearest to when: looney, continental, documentary, sphincter, moreover, sites, unborn, could,
# Nearest to about: golfers, royals, xyz, ange, postcolonial, structure, shinoda, bee,
# Nearest to th: award, gj, christi, wrongful, buson, pastor, jeanette, four,
# Nearest to most: palomar, dogmatically, lott, more, zapatista, mol, parishioners, because,
# Nearest to six: eight, five, seven, four, three, nine, two, zero,
# Nearest to united: imperialist, icmp, touches, porridge, naia, evenings, lagoon, silky,
# Nearest to during: prinz, definitive, oracles, seleucids, ribbon, citt, carthusian, brim,
# Nearest to would: will, can, should, could, killian, may, valera, cavity,
# Nearest to it: he, she, this, not, they, there, also, that,
# Nearest to that: which, plurals, however, it, portsmouth, paleontology, this, cosby,
# Nearest to or: and, riaa, than, admit, disquiet, abrogated, backwaters, of,
# Average loss at step 12000: 3.605819
# Average loss at step 14000: 3.574637
# Average loss at step 16000: 3.414305
# Average loss at step 18000: 3.459261
# Average loss at step 20000: 3.544982
# Nearest to may: can, would, must, should, will, could, lepers, cannot,
# Nearest to been: be, by, typically, setting, were, was, is, yves,
# Nearest to at: in, during, on, with, coca, visited, and, from,
# Nearest to a: any, granddaughter, pains, activism, reconstructionist, no, products, concerned,
# Nearest to first: same, next, last, mpls, second, earth, silky, only,
# Nearest to when: if, does, where, could, unborn, with, after, ductile,
# Nearest to about: bee, xyz, beheading, royals, golfers, structure, corrupted, huron,
# Nearest to th: award, wrongful, christi, aborted, buson, jeanette, inch, pastor,
# Nearest to most: more, palomar, many, some, zapatista, kaposi, kanchenjunga, vedas,
# Nearest to six: eight, four, seven, nine, five, three, zero, two,
# Nearest to united: icmp, porridge, imperialist, lagoon, evenings, naia, touches, spook,
# Nearest to during: at, definitive, prinz, from, after, in, comedians, greaves,
# Nearest to would: will, could, can, should, may, must, might, to,
# Nearest to it: he, this, she, there, they, which, not, only,
# Nearest to that: which, however, what, almost, but, cosby, plurals, this,
# Nearest to or: and, than, no, bloom, yogi, saltpeter, ln, castillian,
# Average loss at step 22000: 3.503097
# Average loss at step 24000: 3.491933
# Average loss at step 26000: 3.485224
# Average loss at step 28000: 3.480293
# Average loss at step 30000: 3.506483
# Nearest to may: can, would, should, must, will, could, cannot, might,
# Nearest to been: be, was, by, were, become, typically, setting, already,
# Nearest to at: in, during, bodybuilding, on, shattuck, inclination, visited, mooted,
# Nearest to a: activism, no, any, the, granddaughter, standpoint, dispatches, denominational,
# Nearest to first: last, next, second, same, collated, final, speculator, home,
# Nearest to when: if, where, after, during, with, but, before, was,
# Nearest to about: bee, beheading, structure, royals, xyz, ngos, golfers, mirza,
# Nearest to th: nd, award, stairway, inch, wrongful, christi, aborted, mainstays,
# Nearest to most: some, more, many, among, palomar, bicentennial, porridge, kaposi,
# Nearest to six: four, eight, five, seven, nine, three, two, zero,
# Nearest to united: icmp, imperialist, evenings, lagoon, porridge, western, spook, silky,
# Nearest to during: in, after, at, when, from, before, definitive, ribbon,
# Nearest to would: will, can, could, may, should, must, might, to,
# Nearest to it: he, this, there, she, they, which, also, not,
# Nearest to that: which, what, however, this, but, batista, wormwood, thus,
# Nearest to or: and, than, castillian, bloom, dun, gottwald, moguls, cristina,
# Average loss at step 32000: 3.506879
# Average loss at step 34000: 3.491958
# Average loss at step 36000: 3.454412
# Average loss at step 38000: 3.302050
# Average loss at step 40000: 3.431362
# Nearest to may: can, would, should, must, will, could, might, cannot,
# Nearest to been: be, become, was, were, typically, setting, yves, had,
# Nearest to at: during, bodybuilding, on, in, galley, mooted, bytecode, tuxedo,
# Nearest to a: the, granddaughter, any, another, activism, folded, pa, denominational,
# Nearest to first: last, next, second, same, home, final, vinod, topless,
# Nearest to when: if, where, before, until, after, with, during, because,
# Nearest to about: bee, beheading, earners, ngos, mirza, structure, royals, jamiroquai,
# Nearest to th: nd, rd, stairway, five, christi, aborted, three, intercity,
# Nearest to most: more, some, many, porridge, less, transaction, among, kaposi,
# Nearest to six: four, seven, five, eight, nine, three, two, one,
# Nearest to united: porridge, lagoon, evenings, imperialist, icmp, western, spook, during,
# Nearest to during: after, at, before, in, when, from, under, comedians,
# Nearest to would: will, can, could, may, should, must, might, cannot,
# Nearest to it: he, there, she, they, this, which, you, only,
# Nearest to that: which, this, what, however, batista, where, paleontology, who,
# Nearest to or: and, than, sara, is, wave, saltpeter, shelling, from,
# Average loss at step 42000: 3.434321
# Average loss at step 44000: 3.458884
# Average loss at step 46000: 3.449655
# Average loss at step 48000: 3.351113
# Average loss at step 50000: 3.390740
# Nearest to may: can, should, would, must, will, could, might, cannot,
# Nearest to been: become, be, were, was, had, already, iraqi, begun,
# Nearest to at: during, from, in, on, bodybuilding, satirists, tuxedo, lesion,
# Nearest to a: granddaughter, the, another, activism, any, denominational, dispatches, pains,
# Nearest to first: last, next, second, same, final, speculator, fourth, only,
# Nearest to when: if, after, where, while, until, before, but, during,
# Nearest to about: bee, ngos, earners, beheading, roskilde, eleven, workhorse, mirza,
# Nearest to th: six, nd, three, rd, five, ad, bc, aborted,
# Nearest to most: more, some, many, less, bicentennial, kaposi, attainder, celtiberian,
# Nearest to six: eight, seven, four, nine, five, three, two, zero,
# Nearest to united: porridge, evenings, lagoon, spain, imperialist, spook, redgrave, icmp,
# Nearest to during: after, in, when, from, at, before, within, since,
# Nearest to would: will, could, can, may, should, must, might, cannot,
# Nearest to it: he, there, she, this, they, also, still, which,
# Nearest to that: which, however, what, pointe, thus, plurals, where, batista,
# Nearest to or: and, than, sara, finegold, hultsfred, gomes, like, markup,
# Average loss at step 52000: 3.439058
# Average loss at step 54000: 3.426749
# Average loss at step 56000: 3.434090
# Average loss at step 58000: 3.398204
# Average loss at step 60000: 3.393288
# Nearest to may: can, should, would, will, must, could, might, cannot,
# Nearest to been: become, be, was, were, had, already, never, iraqi,
# Nearest to at: in, during, paralipomena, under, harvester, guang, bodybuilding, tankers,
# Nearest to a: any, the, another, activism, every, denominational, epistemological, each,
# Nearest to first: last, next, second, speculator, same, final, only, home,
# Nearest to when: if, before, although, where, after, while, until, during,
# Nearest to about: bee, beheading, on, mirza, earners, ngos, over, spit,
# Nearest to th: five, six, nd, rd, ad, bc, st, stairway,
# Nearest to most: more, some, many, kaposi, less, tinymud, tutankhamun, celtiberian,
# Nearest to six: eight, five, four, seven, nine, three, two, zero,
# Nearest to united: porridge, evenings, lagoon, redgrave, spain, spook, imperialist, jourdan,
# Nearest to during: after, in, before, since, when, within, through, at,
# Nearest to would: will, could, may, can, should, must, might, cannot,
# Nearest to it: he, there, she, this, they, which, we, confucius,
# Nearest to that: which, what, however, this, batista, plurals, but, often,
# Nearest to or: and, than, sara, taller, but, for, federalism, severly,
# Average loss at step 62000: 3.238372
# Average loss at step 64000: 3.262110
# Average loss at step 66000: 3.402148
# Average loss at step 68000: 3.394246
# Average loss at step 70000: 3.363481
# Nearest to may: can, would, should, will, could, must, might, cannot,
# Nearest to been: become, be, were, already, was, had, recently, remained,
# Nearest to at: during, in, paralipomena, tankers, hep, after, kerberos, galliard,
# Nearest to a: the, another, activism, any, this, parisian, maximized, denominational,
# Nearest to first: last, second, next, same, best, third, speculator, drachma,
# Nearest to when: if, while, before, where, because, although, after, though,
# Nearest to about: bee, earners, beheading, mirza, eleven, mot, on, zeal,
# Nearest to th: nd, rd, bc, ad, st, acres, nineteenth, seven,
# Nearest to most: more, many, less, some, all, kaposi, among, lynching,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to united: evenings, lagoon, porridge, redgrave, protagoras, spook, sacked, occupied,
# Nearest to during: after, in, before, through, since, throughout, within, at,
# Nearest to would: will, could, may, can, should, must, might, cannot,
# Nearest to it: he, there, she, this, they, still, also, we,
# Nearest to that: which, what, however, but, batista, this, usually, plurals,
# Nearest to or: and, than, but, like, any, lovers, dorsey, mosley,
# Average loss at step 72000: 3.374772
# Average loss at step 74000: 3.347152
# Average loss at step 76000: 3.319067
# Average loss at step 78000: 3.355688
# Average loss at step 80000: 3.376275
# Nearest to may: can, could, should, will, must, would, might, cannot,
# Nearest to been: become, be, were, was, already, never, recently, come,
# Nearest to at: in, during, on, lollards, frieza, after, proficiency, meld,
# Nearest to a: the, marseillaise, another, granddaughter, refineries, hailstones, activism, formic,
# Nearest to first: last, second, next, speculator, third, final, same, real,
# Nearest to when: if, before, after, during, although, where, because, though,
# Nearest to about: bee, beheading, mot, earners, mirza, approximately, meighen, over,
# Nearest to th: rd, nd, ad, bc, sidebands, st, nineteenth, acres,
# Nearest to most: many, more, some, less, among, lynching, kaposi, celtiberian,
# Nearest to six: eight, seven, four, five, three, nine, two, zero,
# Nearest to united: lagoon, evenings, porridge, protagoras, sixteenth, redgrave, census, occupied,
# Nearest to during: after, in, before, when, through, from, throughout, despite,
# Nearest to would: will, could, may, must, can, should, might, cannot,
# Nearest to it: he, there, she, this, they, we, itself, not,
# Nearest to that: which, however, pointe, what, paleontology, batista, thus, but,
# Nearest to or: and, than, but, while, spectre, joystick, federalism, tremont,
# Average loss at step 82000: 3.407218
# Average loss at step 84000: 3.411340
# Average loss at step 86000: 3.392130
# Average loss at step 88000: 3.352734
# Average loss at step 90000: 3.365803
# Nearest to may: can, could, should, must, will, would, might, cannot,
# Nearest to been: become, be, was, already, were, being, appeared, remained,
# Nearest to at: during, in, on, under, after, guang, hander, disassembled,
# Nearest to a: any, the, every, another, granddaughter, reinhardt, angst, epistemological,
# Nearest to first: last, second, next, same, speculator, third, earliest, best,
# Nearest to when: before, if, after, while, where, until, because, during,
# Nearest to about: bee, mirza, beheading, capitalism, ngos, mot, servicio, around,
# Nearest to th: rd, nd, st, ad, nineteenth, bc, cam, one,
# Nearest to most: many, some, more, among, less, all, celtiberian, kaposi,
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Nearest to united: porridge, lagoon, evenings, protagoras, redgrave, first, census, commonwealth,
# Nearest to during: after, before, through, in, from, until, when, throughout,
# Nearest to would: could, will, can, must, may, might, should, did,
# Nearest to it: he, she, this, there, they, we, itself, often,
# Nearest to that: which, however, what, paleontology, thus, batista, repeatedly, often,
# Nearest to or: and, while, spectre, than, federalism, sara, aida, passau,
# Average loss at step 92000: 3.395246
# Average loss at step 94000: 3.258659
# Average loss at step 96000: 3.356902
# Average loss at step 98000: 3.244306
# Average loss at step 100000: 3.358021
# Nearest to may: can, could, should, must, will, would, might, cannot,
# Nearest to been: become, be, already, recently, remained, come, was, by,
# Nearest to at: during, on, in, under, guang, after, hep, with,
# Nearest to a: another, the, any, seaboard, webmineral, monarchies, epistemological, constructors,
# Nearest to first: last, second, next, third, same, drachma, speculator, fourth,
# Nearest to when: if, before, while, where, after, although, though, because,
# Nearest to about: bee, gdi, mot, mirza, around, beheading, spit, melanoleuca,
# Nearest to th: rd, nd, nineteenth, cam, st, ad, third, fifth,
# Nearest to most: more, less, many, among, some, celtiberian, particularly, kaposi,
# Nearest to six: seven, four, eight, five, nine, three, two, zero,
# Nearest to united: porridge, lagoon, evenings, protagoras, census, sacked, redgrave, avm,
# Nearest to during: in, after, before, through, throughout, until, at, despite,
# Nearest to would: will, could, can, must, may, should, might, cannot,
# Nearest to it: he, she, this, there, they, nothing, itself, realise,
# Nearest to that: which, what, however, batista, where, dicke, who, why,
# Nearest to or: and, than, spectre, sara, while, digging, federalism, syntactically,

# %%
final_embeddings.shape
# Out:
# (50000, 128)

# %%
final_embeddings[0]
# Out:
# array([ -2.35128216e-02,  -1.17405377e-01,  -9.30424333e-02,
#         -1.15381353e-01,  -6.27176538e-02,   5.94416820e-03,
#         -7.03634471e-02,   1.07168570e-01,   7.75033161e-02,
#          3.13256904e-02,   2.27728575e-01,   2.34862920e-02,
#          1.13578543e-01,  -4.07380611e-02,  -1.01989016e-01,
#          6.65047541e-02,  -1.78208016e-03,   7.41010206e-03,
#         -9.40618888e-02,  -1.37883276e-02,  -1.64048493e-01,
#          5.78734204e-02,  -7.55323144e-03,   5.14797866e-02,
#          7.13155195e-02,  -7.32321665e-02,  -3.70040610e-02,
#          1.85294896e-02,   3.50700952e-02,   1.41221374e-01,
#          1.13480844e-01,  -1.64469242e-01,   1.01057164e-01,
#         -9.71891358e-02,   1.55207381e-01,   1.39229661e-02,
#         -5.90510815e-02,   1.69244502e-02,  -6.69140518e-02,
#         -4.86545451e-02,  -4.59817424e-02,  -2.42035165e-01,
#         -3.63717191e-02,   6.11463599e-02,   2.59703398e-02,
#          8.82629305e-02,   2.31498163e-02,   2.44322903e-02,
#         -4.34692502e-02,  -6.25999868e-02,  -3.73250730e-02,
#          2.11950094e-02,   8.72223056e-04,  -1.72793269e-02,
#         -7.08849207e-02,  -7.98409507e-02,  -1.57781001e-02,
#          2.45338567e-02,   1.04593905e-03,  -3.69366352e-03,
#          2.02756841e-04,  -5.91007024e-02,   7.21308663e-02,
#          7.03210160e-02,   1.59585327e-02,   6.37342548e-03,
#          5.76883070e-02,   2.09765024e-02,   6.07953593e-02,
#         -1.59403518e-01,   1.93693805e-02,   1.28530771e-01,
#          2.44897738e-01,  -2.58662719e-02,  -4.88176346e-02,
#          5.75221665e-02,  -5.57711124e-02,  -6.03052974e-02,
#          1.13891877e-01,  -7.98198357e-02,   4.66573574e-02,
#         -9.13852185e-04,  -7.76184946e-02,   8.60989541e-02,
#         -2.82299351e-02,   1.35791466e-01,  -9.58053395e-03,
#          5.60027957e-02,  -1.53529316e-01,  -5.76758794e-02,
#          1.33806273e-01,   1.15244322e-01,  -7.93652013e-02,
#          8.54691491e-02,  -7.01578334e-02,  -3.36701795e-02,
#         -1.76435709e-01,   8.85889158e-02,  -1.71877086e-01,
#          1.54925669e-02,   5.72491921e-02,  -3.57255563e-02,
#         -1.62255183e-01,  -4.85219695e-02,   9.31974780e-03,
#         -5.08153848e-02,   1.34758726e-01,   9.58015993e-02,
#         -6.63550943e-02,   5.20170592e-02,   5.43800108e-02,
#         -4.82684438e-04,  -3.52368951e-02,   1.04934089e-01,
#         -4.71992791e-02,  -1.71826705e-02,  -2.32089087e-02,
#         -1.10687446e-02,   8.05317760e-02,   1.29543155e-01,
#         -1.78905316e-02,  -6.61053956e-02,   1.61269471e-01,
#          1.88671499e-01,  -2.15374112e-01,  -4.31477539e-02,
#          1.19762629e-01,   8.62436295e-02], dtype=float32)

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
two_d_embeddings.shape
# Out:
# (400, 2)

# %%
[reverse_dictionary[i] for i in range(1, 401)][:10]
# Out:
# ['the', 'of', 'and', 'one', 'in', 'a', 'to', 'zero', 'nine', 'two']

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
two_d_embeddings.shape, len(words)
# Out:
# ((400, 2), 400)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
