# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
words[:12]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
len(data), len(count), len(dictionary), len(reverse_dictionary)
# Out:
# (17005207, 50000, 50000, 50000)

# %%
count[:10]
# Out:
# [['UNK', 418391],
#  ('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201),
#  ('a', 325873),
#  ('to', 316376),
#  ('zero', 264975),
#  ('nine', 250430)]

# %%
data[:10]
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'term', 'originated', 'originated', 'as', 'term', 'of']

# %%
len(batch), labels.shape
# Out:
# (8, (8, 1))

# %%
batch
# Out:
# array([12, 12, 12, 12,  6,  6,  6,  6], dtype=int32)

# %%
labels
# Out:
# array([[   6],
#        [ 195],
#        [3084],
#        [5239],
#        [ 195],
#        [  12],
#        [   2],
#        [3084]], dtype=int32)

# %%
vocabulary_size
# Out:
# 50000

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.074644
# Nearest to american: gregorian, dickson, paige, jh, subscribe, sibley, babbitt, autocrat,
# Nearest to one: embodies, ecoregion, purchase, treasures, lutheran, linton, wade, known,
# Nearest to used: floods, planting, mutagens, psionic, tok, brescia, inr, hiroshi,
# Nearest to its: tenor, removal, into, kilo, netware, schenectady, sabine, avitus,
# Nearest to world: criswell, undergraduates, tabor, consonants, translator, emptive, shoghi, accordions,
# Nearest to see: pass, pula, nebula, rebuilding, exchangeable, partaking, disposed, royston,
# Nearest to if: sword, winding, sensor, handful, gregers, finish, detrimental, eminently,
# Nearest to no: beacons, longstanding, body, confession, que, mothers, kochi, infantryman,
# Nearest to eight: adware, pilgrim, sociologists, presentations, sauces, mandeville, paramagnetic, rancho,
# Nearest to state: spreadsheets, mercosur, pickguard, chondrites, combine, iconoclasm, corvinus, curdled,
# Nearest to history: consisting, ammonite, touch, acceded, condemned, ladefoged, rightly, unsophisticated,
# Nearest to years: picard, magnify, manufacture, obsolescence, photographers, antiquark, discordian, moo,
# Nearest to up: inks, loup, sheppard, accomplishments, flattery, trieste, tli, hydroxides,
# Nearest to has: sidelined, jesu, generators, denote, quinn, wrote, shack, avars,
# Nearest to such: selwyn, diligent, spanish, faked, cheerful, purer, gibraltar, taipa,
# Nearest to by: familias, dioscorus, bosnian, guayaquil, token, doomed, indentations, staunchly,
# Average loss at step 2000: 4.370377
# Average loss at step 4000: 3.862668
# Average loss at step 6000: 3.785780
# Average loss at step 8000: 3.688863
# Average loss at step 10000: 3.613330
# Nearest to american: karabiners, canadian, australian, veto, mannerisms, paige, accessible, flaming,
# Nearest to one: four, two, three, eight, six, seven, enrollments, five,
# Nearest to used: considered, afghana, known, found, referred, floods, tok, connections,
# Nearest to its: their, his, the, perpetuation, tenor, netware, arnhem, removal,
# Nearest to world: tabor, translator, montaigne, favorite, shoghi, accordions, undergraduates, consonants,
# Nearest to see: exchangeable, pula, partaking, implies, zeeland, galeon, dismissed, misled,
# Nearest to if: finish, handful, corrode, suppliers, exceedingly, pimlico, sponges, sensor,
# Nearest to no: it, chain, hale, a, afar, calendar, longstanding, justice,
# Nearest to eight: six, nine, four, five, three, seven, zero, two,
# Nearest to state: cherries, official, spreadsheets, chondrites, switchable, price, iconoclasm, combine,
# Nearest to history: eglise, acceded, ammonite, touch, consisting, lethe, each, starvation,
# Nearest to years: retrospective, sharps, abdur, contemporaneous, yams, courland, laundering, accolades,
# Nearest to up: data, adin, flattery, accomplishments, hesitant, recorder, tli, longitudes,
# Nearest to has: had, was, is, have, piro, istat, germain, ishaq,
# Nearest to such: restriction, well, selwyn, comstock, lakatos, taipa, xis, cheerful,
# Nearest to by: was, against, as, on, from, been, with, shipyards,
# Average loss at step 12000: 3.604946
# Average loss at step 14000: 3.570152
# Average loss at step 16000: 3.412236
# Average loss at step 18000: 3.456412
# Average loss at step 20000: 3.539241
# Nearest to american: canadian, australian, karabiners, english, british, accessible, mannerisms, alabama,
# Nearest to one: two, four, three, six, seven, eight, five, nine,
# Nearest to used: known, found, referred, considered, connections, reliever, seen, tok,
# Nearest to its: their, his, the, perpetuation, her, some, any, arnhem,
# Nearest to world: u, translator, tabor, undergraduates, subdivide, market, shoghi, empowerment,
# Nearest to see: misled, galeon, but, exchangeable, conservancy, chipmunks, irwin, freethought,
# Nearest to if: but, when, where, finish, corrode, pleading, pimlico, take,
# Nearest to no: chain, a, retold, hale, taxi, handkerchief, helier, gting,
# Nearest to eight: nine, six, seven, four, five, three, two, zero,
# Nearest to state: cherries, area, price, official, viipuri, armada, tap, berkley,
# Nearest to history: eglise, acceded, lampooned, ammonite, tents, divergences, starvation, style,
# Nearest to years: retrospective, sharps, abdur, vojvodina, upheaval, courland, retires, sceptre,
# Nearest to up: data, him, energetics, accomplishments, recorder, evasion, freely, adin,
# Nearest to has: had, have, was, is, istat, aml, germain, assamese,
# Nearest to such: well, restriction, known, comstock, these, macromolecule, chorus, ameliorate,
# Nearest to by: was, be, were, against, after, with, from, mordecai,
# Average loss at step 22000: 3.505489
# Average loss at step 24000: 3.490158
# Average loss at step 26000: 3.480495
# Average loss at step 28000: 3.479687
# Average loss at step 30000: 3.504911
# Nearest to american: canadian, english, british, australian, karabiners, german, mannerisms, accessible,
# Nearest to one: two, four, seven, eight, three, six, five, nine,
# Nearest to used: known, referred, considered, found, written, called, seen, tok,
# Nearest to its: their, the, his, her, perpetuation, arnhem, astrologer, ghilzai,
# Nearest to world: u, translator, market, vietnam, subdivide, undergraduates, beattie, kazakhs,
# Nearest to see: but, misled, jade, conservancy, zeeland, chipmunks, exchangeable, saigon,
# Nearest to if: when, where, pleading, corrode, though, however, but, miscellaneous,
# Nearest to no: chain, retold, any, hale, serious, a, taxi, penned,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to state: area, government, cherries, berkley, chairperson, northampton, nonstop, price,
# Nearest to history: eglise, acceded, lethe, style, starvation, gacy, worst, divergences,
# Nearest to years: days, months, retrospective, vojvodina, sharps, abdur, laia, yams,
# Nearest to up: him, them, data, freely, recorder, accomplishments, energetics, adin,
# Nearest to has: had, have, is, was, istat, chinaman, aml, having,
# Nearest to such: well, known, these, restriction, comstock, ameliorate, regarded, macromolecule,
# Nearest to by: in, was, were, dioscorus, against, with, as, under,
# Average loss at step 32000: 3.504168
# Average loss at step 34000: 3.492116
# Average loss at step 36000: 3.453054
# Average loss at step 38000: 3.303521
# Average loss at step 40000: 3.430308
# Nearest to american: canadian, british, australian, english, polish, german, french, accessible,
# Nearest to one: seven, six, two, four, eight, five, three, nine,
# Nearest to used: found, considered, referred, known, available, written, regarded, seen,
# Nearest to its: their, his, the, her, arnhem, any, our, capita,
# Nearest to world: u, vietnam, market, tabor, translator, fidelity, undergraduates, montaigne,
# Nearest to see: misled, jade, moussa, irwin, properly, zy, mitochondrial, chipmunks,
# Nearest to if: when, where, pleading, is, couldn, setback, though, t,
# Nearest to no: any, chain, serious, hale, rationalisation, notable, philipp, breatharian,
# Nearest to eight: nine, seven, six, four, five, three, two, one,
# Nearest to state: government, armada, cherries, berkley, price, masoch, nonstop, area,
# Nearest to history: acceded, sontag, biography, lampooned, culture, replicating, eglise, lethe,
# Nearest to years: days, months, decades, khomeini, sharps, vojvodina, courland, abdur,
# Nearest to up: him, them, freely, recorder, back, energetics, data, astrakhan,
# Nearest to has: had, have, was, is, having, commited, keepers, istat,
# Nearest to such: well, known, these, including, restriction, many, comstock, macromolecule,
# Nearest to by: for, as, be, jargon, against, with, dioscorus, gabriel,
# Average loss at step 42000: 3.436720
# Average loss at step 44000: 3.455581
# Average loss at step 46000: 3.452318
# Average loss at step 48000: 3.355477
# Average loss at step 50000: 3.386529
# Nearest to american: australian, canadian, english, british, international, polish, german, european,
# Nearest to one: two, eight, six, seven, four, five, three, nine,
# Nearest to used: known, referred, considered, found, available, written, seen, described,
# Nearest to its: their, his, the, her, perpetuation, our, any, capita,
# Nearest to world: vietnam, u, market, fidelity, graviton, translator, largest, tabor,
# Nearest to see: etc, mitochondrial, jade, list, include, thanksgiving, rlc, stanis,
# Nearest to if: when, where, though, pleading, before, although, chronica, but,
# Nearest to no: any, helier, amplitude, taxi, rationalisation, emu, serious, philipp,
# Nearest to eight: six, seven, nine, four, three, five, one, two,
# Nearest to state: government, price, armada, nonstop, cherries, ruben, cpa, crusading,
# Nearest to history: baseball, sontag, acceded, replicating, worst, biography, starvation, incriminating,
# Nearest to years: days, months, decades, sharps, khomeini, year, vojvodina, abdur,
# Nearest to up: them, him, out, freely, off, back, recorder, energetics,
# Nearest to has: had, have, was, is, having, istat, baen, since,
# Nearest to such: well, known, these, many, restriction, including, regarded, comstock,
# Nearest to by: was, with, toward, under, milgram, mourns, being, against,
# Average loss at step 52000: 3.435588
# Average loss at step 54000: 3.428113
# Average loss at step 56000: 3.436906
# Average loss at step 58000: 3.402237
# Average loss at step 60000: 3.392754
# Nearest to american: australian, canadian, british, european, english, polish, international, shingles,
# Nearest to one: six, four, eight, seven, two, five, three, nine,
# Nearest to used: referred, known, considered, found, written, available, seen, regarded,
# Nearest to its: their, his, the, her, perpetuation, capita, our, your,
# Nearest to world: vietnam, market, maceo, subdivide, u, largest, gulf, tabor,
# Nearest to see: include, jade, list, etc, itanium, incense, includes, can,
# Nearest to if: when, where, though, since, although, pleading, before, however,
# Nearest to no: any, notable, helier, emu, souvenir, alva, amplitude, generalized,
# Nearest to eight: six, nine, four, seven, five, three, one, two,
# Nearest to state: government, price, balance, armada, berkley, davidic, nonstop, cpa,
# Nearest to history: development, status, science, baseball, geography, culture, philosophy, sontag,
# Nearest to years: days, months, decades, khomeini, sharps, centuries, year, minutes,
# Nearest to up: him, them, out, off, back, freely, down, recorder,
# Nearest to has: had, have, is, was, having, istat, claiming, bullion,
# Nearest to such: well, known, these, many, restriction, regarded, describing, taipa,
# Nearest to by: through, without, warwick, against, marksman, satem, maaouya, wagoner,
# Average loss at step 62000: 3.239843
# Average loss at step 64000: 3.252426
# Average loss at step 66000: 3.404204
# Average loss at step 68000: 3.394172
# Average loss at step 70000: 3.361203
# Nearest to american: australian, canadian, british, english, european, polish, shingles, international,
# Nearest to one: two, six, four, seven, eight, five, nine, three,
# Nearest to used: known, referred, available, written, considered, found, seen, responsible,
# Nearest to its: their, his, her, the, our, perpetuation, your, capita,
# Nearest to world: vietnam, gulf, u, country, maceo, largest, subdivide, market,
# Nearest to see: include, but, and, list, jade, incense, curie, stanis,
# Nearest to if: when, though, where, however, pleading, although, chronica, since,
# Nearest to no: any, little, notable, philipp, souvenir, emu, helier, alva,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to state: government, putting, cherries, nonstop, city, states, sharif, armada,
# Nearest to history: culture, period, sontag, wisegirls, style, izz, biography, list,
# Nearest to years: days, months, decades, year, centuries, hours, sharps, minutes,
# Nearest to up: them, him, out, off, down, back, freely, astrakhan,
# Nearest to has: had, have, is, was, having, claiming, since, includes,
# Nearest to such: these, well, known, many, including, regarded, follows, other,
# Nearest to by: through, warwick, using, as, be, maaouya, earner, chewed,
# Average loss at step 72000: 3.378730
# Average loss at step 74000: 3.352891
# Average loss at step 76000: 3.316668
# Average loss at step 78000: 3.356476
# Average loss at step 80000: 3.379317
# Nearest to american: canadian, australian, british, polish, european, international, english, belgian,
# Nearest to one: seven, six, two, eight, three, four, five, nine,
# Nearest to used: referred, known, available, responsible, written, found, considered, seen,
# Nearest to its: their, his, the, her, our, your, perpetuation, migration,
# Nearest to world: vietnam, maceo, u, country, fidelity, howto, translator, market,
# Nearest to see: but, according, include, references, jade, list, lindbergh, includes,
# Nearest to if: when, though, where, since, pleading, cannot, chronica, then,
# Nearest to no: any, philipp, little, obliterated, notable, helier, souvenir, sufficient,
# Nearest to eight: six, nine, seven, five, four, three, two, one,
# Nearest to state: government, city, armada, area, assumption, cherries, crusading, putting,
# Nearest to history: list, picts, rebellions, style, culture, sontag, izz, cameroonian,
# Nearest to years: days, months, decades, year, times, centuries, minutes, khomeini,
# Nearest to up: them, out, him, off, down, back, energetics, voice,
# Nearest to has: had, have, is, was, having, claiming, includes, since,
# Nearest to such: well, these, known, follows, including, certain, regarded, described,
# Nearest to by: through, when, maaouya, warwick, from, earner, after, bengali,
# Average loss at step 82000: 3.407337
# Average loss at step 84000: 3.408333
# Average loss at step 86000: 3.389265
# Average loss at step 88000: 3.354238
# Average loss at step 90000: 3.366931
# Nearest to american: australian, canadian, british, polish, european, english, french, austrian,
# Nearest to one: seven, two, eight, four, six, three, five, nine,
# Nearest to used: referred, known, considered, available, responsible, seen, found, designed,
# Nearest to its: their, his, her, the, our, your, perpetuation, my,
# Nearest to world: vietnam, maceo, country, gulf, largest, market, subdivide, translator,
# Nearest to see: list, include, aria, references, jade, includes, curie, but,
# Nearest to if: when, where, though, since, must, although, pleading, chronica,
# Nearest to no: any, little, sufficient, karaites, serious, entscheidungsproblem, only, nothing,
# Nearest to eight: seven, nine, five, six, four, three, two, one,
# Nearest to state: government, area, city, problem, legislative, armada, district, ruben,
# Nearest to history: list, picts, style, culture, rebellions, cameroonian, publicacion, status,
# Nearest to years: days, months, decades, minutes, year, hours, times, centuries,
# Nearest to up: off, out, them, him, back, down, guidance, voice,
# Nearest to has: had, have, is, having, was, aml, since, bullion,
# Nearest to such: well, known, these, certain, follows, regarded, bari, departures,
# Nearest to by: through, when, against, without, with, warwick, maynooth, nicolau,
# Average loss at step 92000: 3.398968
# Average loss at step 94000: 3.254278
# Average loss at step 96000: 3.357616
# Average loss at step 98000: 3.242768
# Average loss at step 100000: 3.359248
# Nearest to american: canadian, british, australian, international, english, polish, neil, scottish,
# Nearest to one: eight, two, seven, six, five, three, four, nine,
# Nearest to used: referred, available, considered, found, designed, responsible, known, written,
# Nearest to its: their, his, our, the, her, your, perpetuation, whose,
# Nearest to world: maceo, translator, vietnam, country, u, gulf, largest, howto,
# Nearest to see: includes, references, list, include, freethought, jade, curie, aria,
# Nearest to if: when, where, though, since, before, although, chronica, pleading,
# Nearest to no: any, little, sufficient, helier, emu, banjos, legions, unwilling,
# Nearest to eight: nine, seven, six, five, four, three, two, one,
# Nearest to state: government, city, area, price, legislative, armada, district, criticises,
# Nearest to history: list, picts, culture, publicacion, cameroonian, rebellions, pisan, semite,
# Nearest to years: days, months, decades, year, minutes, times, weeks, hours,
# Nearest to up: out, off, them, him, back, down, together, guidance,
# Nearest to has: had, have, is, was, having, since, istat, aml,
# Nearest to such: well, known, these, certain, regarded, follows, many, including,
# Nearest to by: through, without, when, shatz, warwick, goren, while, cabaret,

# %%
final_embeddings.shape
# Out:
# (50000, 128)

# %%
final_embeddings[0]
# Out:
# array([-0.06986112, -0.02949237, -0.00333607,  0.121225  , -0.01252212,
#         0.04877383, -0.14641275, -0.10334428, -0.0949094 ,  0.01860846,
#         0.03766803,  0.08452526,  0.12326035, -0.0159167 ,  0.02603518,
#         0.0305548 ,  0.03230033,  0.02009895,  0.01430748, -0.01821993,
#         0.0563893 ,  0.08962435,  0.20632467, -0.02415829,  0.0452315 ,
#         0.1585926 ,  0.09498765,  0.18018271,  0.17739651, -0.01440346,
#        -0.0019839 ,  0.01970565,  0.05446554,  0.03266026,  0.06230509,
#        -0.01824064,  0.06884449,  0.07247252,  0.0901012 , -0.11264658,
#        -0.09755405,  0.05557066, -0.07907604,  0.07277776,  0.06637307,
#         0.08434021, -0.01419269, -0.12539259,  0.02441732,  0.14569947,
#         0.02680912, -0.04317435,  0.02843072,  0.11806405, -0.15524347,
#        -0.08231414, -0.09430286,  0.06016087, -0.04711793, -0.14984772,
#        -0.06476745, -0.02898903, -0.09317052, -0.15493524, -0.0340542 ,
#        -0.18396699, -0.09838929,  0.04781244, -0.06351595, -0.02200131,
#         0.19651656,  0.0651212 , -0.01363331, -0.01721615,  0.08280244,
#        -0.14394628, -0.04589599,  0.05433119,  0.12965403,  0.07311431,
#         0.06828465,  0.10531545,  0.01269943, -0.0724372 , -0.00186464,
#         0.17377748, -0.02858536, -0.0638723 , -0.0597717 ,  0.16112354,
#         0.15835786,  0.00891487, -0.03417936,  0.05572375, -0.06184953,
#        -0.00266134, -0.00153626,  0.05472174, -0.00527166, -0.01610933,
#         0.04595082,  0.21941252,  0.08683729, -0.01883842, -0.04210457,
#         0.03181109,  0.10380822,  0.01957812, -0.06366478,  0.01396655,
#         0.04658245, -0.07632028, -0.00902994,  0.14846334,  0.1632822 ,
#         0.08648259,  0.04755626,  0.02245556, -0.12399028, -0.00645608,
#         0.00504962, -0.03380164, -0.1518566 , -0.01608304, -0.13138273,
#        -0.07627415,  0.15689155, -0.1195921 ], dtype=float32)

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
two_d_embeddings.shape
# Out:
# (400, 2)

# %%
[reverse_dictionary[i] for i in range(1, 401)][:10]
# Out:
# ['the', 'of', 'and', 'one', 'in', 'a', 'to', 'zero', 'nine', 'two']

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
two_d_embeddings.shape, len(words)
# Out:
# ((400, 2), 400)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, context_window):
  global data_index
  #assert batch_size % num_skips == 0
  #assert num_skips <= 2 * skip_window
  context_size = 2 * context_window
  batch = np.ndarray(shape=(batch_size, context_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * context_window + 1 # [ context_window target context_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # context tokens are just all the tokens in buffer except the target
    batch[i, :] = [token for idx, token in enumerate(buffer) if idx != context_window]
    labels[i, 0] = buffer[context_window]
#    target = skip_window  # target label at the center of the buffer
#    targets_to_avoid = [ skip_window ]
#    for j in range(num_skips):
#      while target in targets_to_avoid:
#        target = random.randint(0, span - 1)
#      targets_to_avoid.append(target)
#      batch[i * num_skips + j] = buffer[skip_window]
#      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for context_window in [1, 2, 3]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, context_window=context_window)
    print('\nwith context_window = %d:' % (context_window))
    for elem in batch:
        print ('    batch:', [reverse_dictionary[bi] for bi in elem])
    print ('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
    #print('    batch:', [reverse_dictionary[bi] for bi in batch])
    #print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with context_window = 1:
#     batch: ['anarchism', 'as']
#     batch: ['originated', 'a']
#     batch: ['as', 'term']
#     batch: ['a', 'of']
#     batch: ['term', 'abuse']
#     batch: ['of', 'first']
#     batch: ['abuse', 'used']
#     batch: ['first', 'against']
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with context_window = 2:
#     batch: ['anarchism', 'originated', 'a', 'term']
#     batch: ['originated', 'as', 'term', 'of']
#     batch: ['as', 'a', 'of', 'abuse']
#     batch: ['a', 'term', 'abuse', 'first']
#     batch: ['term', 'of', 'first', 'used']
#     batch: ['of', 'abuse', 'used', 'against']
#     batch: ['abuse', 'first', 'against', 'early']
#     batch: ['first', 'used', 'early', 'working']
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#
# with context_window = 3:
#     batch: ['anarchism', 'originated', 'as', 'term', 'of', 'abuse']
#     batch: ['originated', 'as', 'a', 'of', 'abuse', 'first']
#     batch: ['as', 'a', 'term', 'abuse', 'first', 'used']
#     batch: ['a', 'term', 'of', 'first', 'used', 'against']
#     batch: ['term', 'of', 'abuse', 'used', 'against', 'early']
#     batch: ['of', 'abuse', 'first', 'against', 'early', 'working']
#     batch: ['abuse', 'first', 'used', 'early', 'working', 'class']
#     batch: ['first', 'used', 'against', 'working', 'class', 'radicals']
#     labels: ['a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
context_window = 1  # How many words to consider left and right.
context_size = 2 * context_window

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, context_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # take mean of embeddings of context words for context embedding
  embed_context = tf.reduce_mean(embed, 1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed_context,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, context_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.594915
# Nearest to however: galatia, mi, subtlety, immaturity, clarinetist, straddling, scripting, oils,
# Nearest to had: replicant, andromache, cymbal, sonatas, devoid, groundbreaking, hao, zanu,
# Nearest to years: eccentricity, sikhs, removes, hermon, peru, tempestuous, irma, papeete,
# Nearest to so: absence, pinpoint, willi, deviating, dahomey, undergraduates, ish, odessa,
# Nearest to seven: goya, swell, recapitulation, calico, doesburg, ramp, clocked, cellars,
# Nearest to may: albret, cystic, reacted, jacquard, transplants, twenty, atone, dumbarton,
# Nearest to two: shortly, calculi, ungrammatical, crudely, resounding, lejeune, newnode, ribozymes,
# Nearest to all: afflicted, enco, misdemeanors, meteors, macrobiotics, recites, bestseller, nominated,
# Nearest to on: speculations, orphaned, zapatistas, short, clint, memos, borders, forecasting,
# Nearest to he: konqueror, conner, sint, pivotal, leni, crafts, coil, ayub,
# Nearest to some: subpixel, rhetoricians, kilobytes, leakey, flaming, atrophy, sappho, rhyming,
# Nearest to who: sanguine, perugia, frisbee, accelerating, plaintexts, pulses, boundless, gland,
# Nearest to used: cares, bios, mattel, yehuda, porridge, transient, gottwald, travels,
# Nearest to nine: format, beatle, phillip, dishonesty, conjugation, deduce, attracts, bachchan,
# Nearest to can: arid, legislated, pans, wahid, oleg, agencies, transitioning, canso,
# Nearest to when: aftermath, those, romney, frantic, motions, barnett, iso, ncbi,
# Average loss at step 2000: 4.039129
# Average loss at step 4000: 3.508053
# Average loss at step 6000: 3.340143
# Average loss at step 8000: 3.198997
# Average loss at step 10000: 3.151845
# Nearest to however: mi, wasps, minded, could, when, galatia, sweyn, clarinetist,
# Nearest to had: has, was, were, have, replicant, never, gums, iowa,
# Nearest to years: caenorhabditis, loner, cathedral, sikhs, tempestuous, leave, eccentricity, gracie,
# Nearest to so: sweets, demarco, mengistu, deviating, polygamous, dahomey, ground, henry,
# Nearest to seven: nine, eight, six, five, zero, four, three, two,
# Nearest to may: can, would, should, will, must, cannot, could, touchdowns,
# Nearest to two: five, three, four, one, six, eight, seven, nine,
# Nearest to all: afflicted, enco, litigation, mandaeanism, stair, interwoven, storefront, classifying,
# Nearest to on: in, photons, autocorrelation, fused, sundial, overall, collected, against,
# Nearest to he: it, she, who, they, there, sint, xi, rhodope,
# Nearest to some: many, these, amazingly, his, accusations, unauthorised, indeterminate, wingless,
# Nearest to who: he, often, they, tyrell, masurian, opinions, tremors, boundless,
# Nearest to used: cares, ortelius, dreaming, known, bios, porridge, hybrid, spirits,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to can: would, may, will, should, might, could, must, flanders,
# Nearest to when: yelling, however, hoarding, blamed, hastily, barbie, bernie, zh,
# Average loss at step 12000: 3.175951
# Average loss at step 14000: 3.128776
# Average loss at step 16000: 3.149727
# Average loss at step 18000: 3.103473
# Average loss at step 20000: 2.995179
# Nearest to however: but, wasps, mi, although, that, when, finiteness, sweyn,
# Nearest to had: has, have, was, were, never, already, hussein, autopilot,
# Nearest to years: caenorhabditis, loner, times, platform, tempestuous, sikhs, kuo, cathedral,
# Nearest to so: sweets, neuron, ground, paleontologists, throttled, rios, mengistu, drifted,
# Nearest to seven: six, eight, nine, five, four, zero, three, two,
# Nearest to may: can, would, will, should, cannot, could, must, might,
# Nearest to two: three, six, four, seven, one, five, eight, nine,
# Nearest to all: afflicted, enco, classifying, interwoven, some, neuroscientist, litigation, konstantin,
# Nearest to on: upon, in, fused, nanometer, museu, autocorrelation, borders, during,
# Nearest to he: it, she, they, there, who, xi, languedoc, sint,
# Nearest to some: many, these, amazingly, numerous, several, both, wingless, their,
# Nearest to who: he, often, they, masurian, she, agm, eventually, tyrell,
# Nearest to used: known, cares, ortelius, referred, dreaming, cited, written, bios,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to can: may, would, will, could, might, should, must, cannot,
# Nearest to when: if, before, zh, yelling, however, after, because, fraternal,
# Average loss at step 22000: 3.052190
# Average loss at step 24000: 3.023446
# Average loss at step 26000: 2.990737
# Average loss at step 28000: 3.017715
# Average loss at step 30000: 2.989310
# Nearest to however: but, although, finiteness, though, wasps, that, ago, when,
# Nearest to had: has, have, was, were, already, never, hussein, autopilot,
# Nearest to years: days, loner, caenorhabditis, times, platform, decades, kuo, months,
# Nearest to so: bdp, drifted, contemporaneously, paleontologists, neuron, padua, ephemeral, argues,
# Nearest to seven: eight, six, four, nine, five, zero, three, two,
# Nearest to may: can, would, will, could, should, might, cannot, must,
# Nearest to two: three, four, six, five, seven, one, eight, nine,
# Nearest to all: afflicted, every, these, some, enco, classifying, isotropy, both,
# Nearest to on: upon, in, fused, through, overall, borders, dualist, goshen,
# Nearest to he: she, it, they, there, who, eventually, cegep, languedoc,
# Nearest to some: many, these, several, amazingly, numerous, most, all, both,
# Nearest to who: he, masurian, they, eventually, she, agm, often, which,
# Nearest to used: known, referred, cares, bios, ortelius, cited, dreaming, able,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to can: may, would, will, could, might, should, must, cannot,
# Nearest to when: if, before, after, because, however, where, zh, during,
# Average loss at step 32000: 2.842397
# Average loss at step 34000: 2.950170
# Average loss at step 36000: 2.937600
# Average loss at step 38000: 2.934319
# Average loss at step 40000: 2.920749
# Nearest to however: but, although, though, that, wasps, ago, when, finiteness,
# Nearest to had: has, have, was, were, recently, never, hussein, already,
# Nearest to years: days, months, decades, times, loner, caenorhabditis, weeks, platform,
# Nearest to so: neuron, contemporaneously, durand, throttled, bdp, drifted, how, sca,
# Nearest to seven: eight, six, five, four, nine, three, zero, two,
# Nearest to may: can, would, will, could, might, should, cannot, must,
# Nearest to two: three, four, six, five, seven, eight, one, nine,
# Nearest to all: every, both, afflicted, classifying, depopulation, some, abduction, mich,
# Nearest to on: upon, through, in, promote, photons, fused, governing, stratification,
# Nearest to he: she, it, they, there, who, eventually, sint, languedoc,
# Nearest to some: many, these, several, numerous, amazingly, various, both, most,
# Nearest to who: he, they, eventually, often, masurian, she, uruk, which,
# Nearest to used: referred, known, cited, seen, able, allowed, responsible, callet,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to can: may, could, will, would, might, should, must, cannot,
# Nearest to when: if, before, after, because, however, zh, during, yelling,
# Average loss at step 42000: 2.944312
# Average loss at step 44000: 2.947790
# Average loss at step 46000: 2.909209
# Average loss at step 48000: 2.869538
# Average loss at step 50000: 2.844103
# Nearest to however: but, although, though, that, wasps, while, especially, ago,
# Nearest to had: has, have, was, were, recently, never, having, already,
# Nearest to years: days, decades, months, weeks, loner, times, caenorhabditis, centuries,
# Nearest to so: contemporaneously, neuron, how, durand, bdp, too, throttled, indicates,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to may: can, could, would, will, might, should, cannot, must,
# Nearest to two: three, four, six, five, seven, eight, one, nine,
# Nearest to all: both, many, every, some, afflicted, several, depopulation, classifying,
# Nearest to on: upon, through, under, in, photons, within, autocorrelation, overall,
# Nearest to he: she, it, they, there, who, eventually, hemispheric, languedoc,
# Nearest to some: many, several, these, numerous, various, most, amazingly, all,
# Nearest to who: he, eventually, often, masurian, she, initially, which, confessor,
# Nearest to used: referred, known, seen, cited, written, able, allowed, responsible,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to can: may, could, will, would, must, might, should, cannot,
# Nearest to when: if, before, after, because, where, during, while, yelling,
# Average loss at step 52000: 2.880623
# Average loss at step 54000: 2.862951
# Average loss at step 56000: 2.858908
# Average loss at step 58000: 2.761297
# Average loss at step 60000: 2.826946
# Nearest to however: but, although, though, that, especially, wasps, when, within,
# Nearest to had: has, have, was, were, having, recently, ever, never,
# Nearest to years: months, days, decades, weeks, times, centuries, loner, year,
# Nearest to so: how, too, contemporaneously, neuron, bdp, throttled, durand, indicates,
# Nearest to seven: five, six, eight, nine, four, three, zero, two,
# Nearest to may: can, could, will, would, might, should, must, cannot,
# Nearest to two: three, four, six, five, one, eight, seven, nine,
# Nearest to all: both, many, various, depopulation, classifying, these, afflicted, several,
# Nearest to on: upon, through, within, in, under, photons, stansted, during,
# Nearest to he: she, it, they, there, who, eventually, we, languedoc,
# Nearest to some: many, several, these, numerous, most, amazingly, any, various,
# Nearest to who: he, often, she, eventually, still, they, initially, masurian,
# Nearest to used: referred, known, seen, able, cited, considered, written, allowed,
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to can: could, may, will, would, must, should, cannot, might,
# Nearest to when: if, before, after, during, because, where, while, though,
# Average loss at step 62000: 2.835316
# Average loss at step 64000: 2.779657
# Average loss at step 66000: 2.769993
# Average loss at step 68000: 2.719661
# Average loss at step 70000: 2.776968
# Nearest to however: but, although, though, that, especially, while, wasps, where,
# Nearest to had: has, have, was, having, were, ever, recently, never,
# Nearest to years: months, days, decades, weeks, times, centuries, year, loner,
# Nearest to so: too, contemporaneously, throttled, neuron, bdp, durand, how, thus,
# Nearest to seven: eight, five, six, nine, four, three, zero, two,
# Nearest to may: can, could, will, might, should, would, cannot, must,
# Nearest to two: three, four, five, six, seven, eight, nine, one,
# Nearest to all: both, many, various, depopulation, some, afflicted, these, classifying,
# Nearest to on: upon, in, through, within, under, during, autocorrelation, photons,
# Nearest to he: she, it, they, there, who, eventually, languedoc, hemispheric,
# Nearest to some: many, several, numerous, these, most, various, certain, both,
# Nearest to who: he, she, eventually, often, initially, still, masurian, they,
# Nearest to used: referred, known, seen, allowed, able, considered, applied, necessary,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to can: could, may, will, might, must, should, would, cannot,
# Nearest to when: if, before, after, where, because, while, during, though,
# Average loss at step 72000: 2.798080
# Average loss at step 74000: 2.655544
# Average loss at step 76000: 2.803158
# Average loss at step 78000: 2.825630
# Average loss at step 80000: 2.786532
# Nearest to however: but, although, though, that, especially, and, while, wasps,
# Nearest to had: has, have, was, were, having, recently, ever, never,
# Nearest to years: months, decades, days, weeks, times, centuries, year, loner,
# Nearest to so: too, contemporaneously, bdp, durand, neuron, throttled, how, thus,
# Nearest to seven: six, five, eight, nine, four, three, zero, two,
# Nearest to may: can, could, would, might, will, should, cannot, must,
# Nearest to two: three, four, six, five, eight, seven, one, nine,
# Nearest to all: both, many, various, several, some, afflicted, every, depopulation,
# Nearest to on: upon, in, through, within, promote, during, against, nanometer,
# Nearest to he: she, it, they, there, who, hemispheric, eventually, allegedly,
# Nearest to some: many, several, numerous, these, certain, various, most, all,
# Nearest to who: he, she, initially, often, eventually, still, masurian, which,
# Nearest to used: referred, known, seen, able, responsible, needed, cited, considered,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to can: could, may, will, would, might, must, cannot, should,
# Nearest to when: if, before, after, while, where, during, although, because,
# Average loss at step 82000: 2.675164
# Average loss at step 84000: 2.773537
# Average loss at step 86000: 2.740853
# Average loss at step 88000: 2.759060
# Average loss at step 90000: 2.742164
# Nearest to however: but, although, though, that, while, especially, additionally, electronica,
# Nearest to had: has, have, was, having, were, recently, ever, jacobs,
# Nearest to years: decades, months, days, weeks, centuries, times, year, hours,
# Nearest to so: too, neuron, contemporaneously, durand, how, bdp, drifted, throttled,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to may: can, could, would, might, will, should, cannot, must,
# Nearest to two: three, four, six, five, eight, seven, one, nine,
# Nearest to all: both, many, various, some, several, every, classifying, any,
# Nearest to on: upon, in, through, within, promote, concerning, museu, nanometer,
# Nearest to he: she, it, they, there, eventually, who, allegedly, we,
# Nearest to some: many, several, numerous, these, most, certain, various, both,
# Nearest to who: still, often, he, eventually, initially, she, confessor, always,
# Nearest to used: referred, seen, known, cited, responsible, needed, applied, able,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to can: could, may, will, would, should, must, might, cannot,
# Nearest to when: if, before, where, while, although, after, though, because,
# Average loss at step 92000: 2.692991
# Average loss at step 94000: 2.726775
# Average loss at step 96000: 2.709431
# Average loss at step 98000: 2.390991
# Average loss at step 100000: 2.417770
# Nearest to however: but, although, though, that, while, and, additionally, especially,
# Nearest to had: has, have, was, were, having, recently, ever, niles,
# Nearest to years: decades, months, days, weeks, centuries, year, times, hours,
# Nearest to so: too, thus, how, neuron, contemporaneously, durand, bdp, anything,
# Nearest to seven: six, nine, eight, five, four, three, zero, two,
# Nearest to may: can, might, could, would, will, should, must, cannot,
# Nearest to two: three, six, five, four, seven, eight, nine, zero,
# Nearest to all: both, various, many, some, several, clothed, every, possibilities,
# Nearest to on: upon, through, within, in, nanometer, at, about, promote,
# Nearest to he: she, it, they, there, we, hemispheric, eventually, languedoc,
# Nearest to some: many, several, numerous, certain, these, various, all, any,
# Nearest to who: often, still, survivals, initially, she, eventually, he, which,
# Nearest to used: referred, known, cited, seen, needed, applied, designed, responsible,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to can: could, may, will, cannot, might, would, must, should,
# Nearest to when: if, before, after, while, although, where, though, during,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
