# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
words[:12]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working']

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
len(data), len(count), len(dictionary), len(reverse_dictionary)
# Out:
# (17005207, 50000, 50000, 50000)

# %%
count[:10]
# Out:
# [['UNK', 418391],
#  ('the', 1061396),
#  ('of', 593677),
#  ('and', 416629),
#  ('one', 411764),
#  ('in', 372201),
#  ('a', 325873),
#  ('to', 316376),
#  ('zero', 264975),
#  ('nine', 250430)]

# %%
data[:10]
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'a', 'originated', 'of', 'as', 'term', 'originated']

# %%
len(batch), labels.shape
# Out:
# (8, (8, 1))

# %%
batch
# Out:
# array([12, 12, 12, 12,  6,  6,  6,  6], dtype=int32)

# %%
labels
# Out:
# array([[5239],
#        [ 195],
#        [   6],
#        [3084],
#        [   2],
#        [  12],
#        [ 195],
#        [3084]], dtype=int32)

# %%
vocabulary_size
# Out:
# 50000

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  nce_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  nce_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.nce_loss(weights=nce_weights, biases=nce_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 260.601288
# Nearest to after: mandaeans, beaconsfield, hayek, defines, dum, courting, cyborg, reveals,
# Nearest to no: assassinate, throne, ojibwa, allied, indication, spaces, delos, antitrust,
# Nearest to for: newsgroup, mexican, kharkov, jpl, maurice, receded, asshole, accrued,
# Nearest to states: ruin, hurrian, producers, georgi, pinkish, shamanic, nsync, chiuchow,
# Nearest to also: sufficient, pathfinder, miya, definitional, emigrate, polygamous, drifted, lobster,
# Nearest to have: incised, canis, suffragette, camino, prevalence, bytes, generates, chester,
# Nearest to had: carpathian, push, strat, cfo, tied, nachrichten, kou, renovated,
# Nearest to two: advancements, sarcoma, labyrinths, iroquois, trends, manly, bogs, phenomenology,
# Nearest to called: poultry, ceding, disregards, approximants, matic, amphibians, bk, muharram,
# Nearest to eight: jonny, ambivalent, civilize, azzam, illnesses, dynamic, antiquarian, sassanians,
# Nearest to b: calculations, xis, rushing, walden, chungcheong, nnhilde, klaproth, markka,
# Nearest to an: bukhara, etching, abbess, guard, taxonomy, magdeburg, erythromycin, debug,
# Nearest to time: jiu, preoccupations, fic, lustrous, bacteria, hume, heifer, fyodor,
# Nearest to often: nodules, incompleteness, moshiach, abakan, labour, understandings, daimler, gods,
# Nearest to use: stunted, alleges, avm, omnia, unsubstantiated, median, bentsen, zuse,
# Nearest to world: stems, absinthe, reunite, kitt, airstrip, geer, micah, arouse,
# Average loss at step 2000: 109.552450
# Average loss at step 4000: 51.679535
# Average loss at step 6000: 32.674164
# Average loss at step 8000: 23.064322
# Average loss at step 10000: 17.401456
# Nearest to after: in, from, with, and, for, during, reshaping, as,
# Nearest to no: who, it, an, a, accelerate, mazar, thirds, yew,
# Nearest to for: in, from, and, of, with, or, at, on,
# Nearest to states: psychotic, siding, flagellates, georgi, richer, disposing, footballer, primate,
# Nearest to also: often, which, it, not, insist, cucumbers, by, who,
# Nearest to have: had, be, has, are, were, polled, was, tractor,
# Nearest to had: has, was, have, were, is, been, are, by,
# Nearest to two: three, four, five, one, eight, six, zero, seven,
# Nearest to called: investors, ric, hindered, and, overviews, amateurs, nucleosynthesis, taunting,
# Nearest to eight: nine, five, four, six, seven, three, zero, two,
# Nearest to b: d, jackie, laborers, robert, wg, afghanistan, agave, pretended,
# Nearest to an: the, it, this, stillborn, no, usaid, velvet, yew,
# Nearest to time: lowly, toleration, shelf, leakey, repeatable, kew, diocesan, commotion,
# Nearest to often: also, who, not, usually, he, meeting, as, gorbachev,
# Nearest to use: unimportant, coining, gst, lace, subtleties, adolphe, purchases, daisies,
# Nearest to world: airstrip, mort, novarum, hausdorff, administers, subdued, electrodynamics, shattering,
# Average loss at step 12000: 13.641619
# Average loss at step 14000: 11.331576
# Average loss at step 16000: 9.504636
# Average loss at step 18000: 8.462028
# Average loss at step 20000: 7.653735
# Nearest to after: before, when, in, from, into, during, at, and,
# Nearest to no: a, which, often, there, it, who, an, this,
# Nearest to for: in, of, at, and, from, with, or, by,
# Nearest to states: psychotic, kingdom, chainmail, cranmer, wishful, loris, nitric, superstars,
# Nearest to also: which, often, usually, who, that, sometimes, not, now,
# Nearest to have: had, has, be, were, are, tractor, being, pairing,
# Nearest to had: has, have, was, were, is, been, are, having,
# Nearest to two: three, five, four, one, six, seven, eight, zero,
# Nearest to called: suck, and, approximants, who, necropolis, investors, irregularity, tenor,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to b: d, german, french, american, english, italian, one, eight,
# Nearest to an: the, no, hedwig, tamara, dikes, stillborn, alegre, wiser,
# Nearest to time: lowly, endlessly, diocesan, pentagonal, planks, morphological, brunei, risc,
# Nearest to often: sometimes, who, also, usually, which, now, commonly, not,
# Nearest to use: tinted, coining, gst, stunted, haber, acidity, unimportant, daisies,
# Nearest to world: administers, mort, first, fluids, shattering, airstrip, chattel, shoguns,
# Average loss at step 22000: 7.066230
# Average loss at step 24000: 6.688170
# Average loss at step 26000: 6.498139
# Average loss at step 28000: 6.005892
# Average loss at step 30000: 6.067539
# Nearest to after: before, during, when, into, through, until, in, at,
# Nearest to no: any, a, this, there, gallium, little, often, only,
# Nearest to for: with, and, of, when, in, while, through, against,
# Nearest to states: kingdom, psychotic, behaving, converge, superstars, shipyard, chipmunks, bellerophon,
# Nearest to also: often, now, which, usually, sometimes, still, there, it,
# Nearest to have: had, were, has, are, be, quincey, being, but,
# Nearest to had: has, have, was, were, became, been, when, is,
# Nearest to two: three, four, five, one, six, seven, eight, zero,
# Nearest to called: dimensionality, swedenborg, suck, but, considered, and, necropolis, bos,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to b: d, french, english, german, american, nine, italian, five,
# Nearest to an: the, pls, homophones, theoretician, abbotsford, sanitary, pgs, velvet,
# Nearest to time: diocesan, tilted, stove, term, battlecruisers, fyodor, if, day,
# Nearest to often: sometimes, usually, also, still, now, commonly, who, generally,
# Nearest to use: form, gst, all, coining, both, acidity, belize, thirsty,
# Nearest to world: administers, fluids, exodus, shattering, first, growths, reunite, westwood,
# Average loss at step 32000: 5.772630
# Average loss at step 34000: 5.741308
# Average loss at step 36000: 5.633467
# Average loss at step 38000: 5.166997
# Average loss at step 40000: 5.388495
# Nearest to after: before, when, during, until, in, under, against, through,
# Nearest to no: a, any, or, usually, nami, some, generally, often,
# Nearest to for: in, if, while, against, on, with, when, from,
# Nearest to states: kingdom, psychotic, converge, behaving, scanline, deathbed, nations, chipmunks,
# Nearest to also: often, now, usually, which, sometimes, still, there, never,
# Nearest to have: had, were, has, are, be, already, like, including,
# Nearest to had: has, have, was, were, became, never, having, when,
# Nearest to two: three, four, five, seven, six, one, eight, zero,
# Nearest to called: and, UNK, but, considered, like, now, de, there,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to b: d, UNK, c, robert, seven, j, three, and,
# Nearest to an: the, halifax, velvet, pls, stillborn, this, messianic, interstates,
# Nearest to time: period, tilted, diocesan, day, way, giulia, term, year,
# Nearest to often: usually, sometimes, also, still, commonly, generally, now, which,
# Nearest to use: form, cinque, rotor, subtleties, mamoru, tinted, sadler, begged,
# Nearest to world: kodansha, administers, hausdorff, shattering, exodus, cervix, time, sveriges,
# Average loss at step 42000: 5.271331
# Average loss at step 44000: 5.190726
# Average loss at step 46000: 5.210774
# Average loss at step 48000: 4.965785
# Average loss at step 50000: 5.144555
# Nearest to after: before, during, when, until, since, while, under, against,
# Nearest to no: any, usually, a, it, actually, commandants, there, this,
# Nearest to for: while, and, from, against, on, through, in, during,
# Nearest to states: kingdom, psychotic, nations, behaving, chipmunks, keeling, ivb, shipyard,
# Nearest to also: often, now, sometimes, still, usually, which, never, generally,
# Nearest to have: had, were, has, be, are, according, like, re,
# Nearest to had: has, have, were, was, been, never, is, became,
# Nearest to two: three, four, six, one, five, eight, seven, zero,
# Nearest to called: but, made, and, used, UNK, animalium, or, like,
# Nearest to eight: six, seven, nine, five, four, three, two, zero,
# Nearest to b: d, c, j, rambla, UNK, r, three, one,
# Nearest to an: the, no, ambiguities, this, velvet, halifax, homophones, stillborn,
# Nearest to time: way, period, year, term, day, case, however, attendances,
# Nearest to often: usually, sometimes, still, generally, commonly, now, also, typically,
# Nearest to use: form, mamoru, shredded, most, subtleties, view, rotor, cinque,
# Nearest to world: kodansha, soundboard, history, nederland, administers, shattering, cervix, domingo,
# Average loss at step 52000: 5.149542
# Average loss at step 54000: 5.075759
# Average loss at step 56000: 5.038487
# Average loss at step 58000: 5.059060
# Average loss at step 60000: 4.913867
# Nearest to after: before, during, when, while, until, against, although, since,
# Nearest to no: any, a, little, commandants, there, usually, spiritualist, or,
# Nearest to for: although, and, while, in, without, against, if, of,
# Nearest to states: kingdom, nations, countries, psychotic, ics, state, ticketing, hesperides,
# Nearest to also: now, often, still, sometimes, usually, never, which, commonly,
# Nearest to have: had, has, were, are, having, include, be, including,
# Nearest to had: has, have, was, were, became, under, having, while,
# Nearest to two: three, four, five, one, six, seven, eight, zero,
# Nearest to called: used, made, named, considered, known, UNK, but, and,
# Nearest to eight: six, seven, nine, five, four, three, zero, one,
# Nearest to b: d, c, UNK, rambla, r, k, j, f,
# Nearest to an: the, ambiguities, this, stillborn, another, redox, theoretician, dikes,
# Nearest to time: way, term, period, case, year, day, lactase, knowledge,
# Nearest to often: sometimes, usually, generally, commonly, still, also, now, typically,
# Nearest to use: form, view, most, cinque, tinted, case, sadler, dred,
# Nearest to world: kodansha, nederland, soundboard, shattering, glendale, cervix, xyz, future,
# Average loss at step 62000: 4.745906
# Average loss at step 64000: 4.738206
# Average loss at step 66000: 4.980852
# Average loss at step 68000: 4.870086
# Average loss at step 70000: 4.745625
# Nearest to after: before, during, when, until, despite, in, through, while,
# Nearest to no: there, or, any, little, and, it, actually, a,
# Nearest to for: in, without, while, including, against, although, when, and,
# Nearest to states: kingdom, nations, countries, state, escorting, sakai, ics, hesperides,
# Nearest to also: often, now, sometimes, still, usually, which, never, generally,
# Nearest to have: had, has, were, are, including, be, include, having,
# Nearest to had: has, have, was, were, became, when, since, having,
# Nearest to two: three, four, one, six, five, seven, eight, zero,
# Nearest to called: but, UNK, and, named, considered, known, used, made,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to b: d, j, r, n, UNK, f, robert, k,
# Nearest to an: the, stillborn, theoretician, pls, ambiguities, halifax, simplicius, disjointed,
# Nearest to time: term, period, case, way, however, possible, year, lactase,
# Nearest to often: usually, sometimes, generally, commonly, now, also, still, typically,
# Nearest to use: form, most, cinque, variadic, case, view, begged, work,
# Nearest to world: kodansha, nederland, country, future, u, bible, writing, shattering,
# Average loss at step 72000: 4.771898
# Average loss at step 74000: 4.754837
# Average loss at step 76000: 4.868881
# Average loss at step 78000: 4.781512
# Average loss at step 80000: 4.816762
# Nearest to after: before, during, when, under, until, despite, in, following,
# Nearest to no: little, any, and, actually, or, there, congruence, this,
# Nearest to for: including, when, in, without, while, against, although, and,
# Nearest to states: kingdom, nations, state, escorting, us, sakai, federal, graces,
# Nearest to also: sometimes, now, often, usually, still, which, actually, never,
# Nearest to have: had, has, were, are, be, having, including, include,
# Nearest to had: has, have, was, were, became, began, when, although,
# Nearest to two: three, four, seven, six, five, one, eight, zero,
# Nearest to called: considered, used, known, named, made, like, swedenborg, provided,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to b: d, c, r, k, j, UNK, p, n,
# Nearest to an: the, this, ambiguities, halifax, theoretician, pls, stillborn, pgs,
# Nearest to time: way, period, case, year, lactase, problem, tilted, fiedler,
# Nearest to often: sometimes, usually, commonly, generally, still, typically, now, also,
# Nearest to use: form, most, variadic, mamoru, all, because, way, both,
# Nearest to world: kodansha, shattering, future, bible, u, term, writing, cervix,
# Average loss at step 82000: 4.802451
# Average loss at step 84000: 4.784730
# Average loss at step 86000: 4.731478
# Average loss at step 88000: 4.651276
# Average loss at step 90000: 4.738326
# Nearest to after: before, during, when, until, despite, while, under, through,
# Nearest to no: little, any, actually, there, usually, only, often, nami,
# Nearest to for: including, when, without, while, against, during, of, in,
# Nearest to states: kingdom, nations, us, state, escorting, countries, graces, behaving,
# Nearest to also: sometimes, often, now, still, usually, actually, which, never,
# Nearest to have: had, has, were, are, be, having, according, include,
# Nearest to had: has, have, was, were, having, although, according, became,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to called: considered, known, used, like, named, and, sometimes, but,
# Nearest to eight: seven, nine, five, six, four, three, zero, two,
# Nearest to b: d, c, j, k, r, UNK, p, f,
# Nearest to an: the, sensitivities, another, ambiguities, dikes, theoretician, always, motorcyclists,
# Nearest to time: way, however, case, period, year, day, when, if,
# Nearest to often: sometimes, usually, generally, commonly, still, typically, now, actually,
# Nearest to use: form, most, all, support, mamoru, case, way, because,
# Nearest to world: kodansha, future, shattering, cervix, however, uninterested, view, xyz,
# Average loss at step 92000: 4.714086
# Average loss at step 94000: 4.573537
# Average loss at step 96000: 4.689801
# Average loss at step 98000: 4.567673
# Average loss at step 100000: 4.659798
# Nearest to after: before, during, when, despite, until, without, under, while,
# Nearest to no: any, little, another, usually, actually, satisfactorily, only, or,
# Nearest to for: including, when, without, if, while, although, in, and,
# Nearest to states: kingdom, nations, state, us, governments, countries, escorting, hesperides,
# Nearest to also: sometimes, now, often, still, usually, actually, never, generally,
# Nearest to have: had, has, were, are, be, according, include, having,
# Nearest to had: has, have, was, were, having, is, wrote, did,
# Nearest to two: three, four, five, six, one, seven, eight, zero,
# Nearest to called: like, and, used, considered, known, named, referred, sometimes,
# Nearest to eight: seven, nine, five, six, four, three, zero, two,
# Nearest to b: d, j, french, c, robert, german, english, actor,
# Nearest to an: the, its, pls, ambiguities, another, sensitivities, dikes, theoretician,
# Nearest to time: way, period, year, day, case, lactase, experience, josaphat,
# Nearest to often: sometimes, usually, generally, commonly, actually, still, typically, now,
# Nearest to use: form, support, most, mamoru, sense, case, cause, because,
# Nearest to world: kodansha, u, future, country, shattering, history, uninterested, bible,

# %%
final_embeddings.shape
# Out:
# (50000, 128)

# %%
final_embeddings[0]
# Out:
# array([  1.89124830e-02,  -1.38874575e-02,  -1.06552564e-01,
#         -6.89664260e-02,   2.21895464e-02,   1.93289712e-01,
#          2.08753254e-03,   5.06687202e-02,   5.85071146e-02,
#          1.18034109e-02,  -3.89698073e-02,  -9.14168283e-02,
#          3.86510454e-02,   1.54016912e-02,   1.62387583e-02,
#          3.21652293e-02,   8.06121677e-02,  -9.87576693e-02,
#          4.36304845e-02,  -5.05500212e-02,  -5.04583903e-02,
#         -2.14023516e-02,   6.90617189e-02,   1.82720087e-02,
#         -3.92590351e-02,  -2.53971945e-02,  -2.43840106e-02,
#          4.25134674e-02,  -3.47056538e-02,   6.11023642e-02,
#          3.45214039e-01,   2.40082797e-02,  -7.29793683e-02,
#          3.98666486e-02,  -2.43776608e-02,   6.82539046e-02,
#         -3.48540694e-02,   7.25806281e-02,  -6.85441121e-02,
#          2.31886599e-02,   1.26433015e-01,   1.97675943e-01,
#          1.45980373e-01,   2.67633557e-04,  -1.38824433e-02,
#          1.55938700e-01,  -1.16106436e-01,   4.49722931e-02,
#         -2.94602942e-02,  -8.88300315e-02,   4.17465866e-02,
#         -5.69896847e-02,   3.30313668e-03,  -1.88265238e-02,
#         -4.86030579e-02,   2.33541080e-03,  -1.64629757e-01,
#         -3.21355984e-02,  -2.00577185e-01,  -4.33502579e-03,
#          3.69073227e-02,  -5.97392544e-02,   2.50124373e-02,
#          4.26803939e-02,  -5.92922606e-02,  -1.12044185e-01,
#          7.18495771e-02,  -1.19831711e-01,  -4.23825812e-03,
#         -2.28414964e-02,  -6.76098019e-02,   6.16472661e-02,
#         -1.17911942e-01,  -1.05480537e-01,   3.72537635e-02,
#          3.66072133e-02,   2.96455231e-02,   2.00475361e-02,
#          1.03594489e-01,   2.90486030e-02,  -1.56101100e-02,
#         -1.33127458e-02,  -1.67676981e-03,   5.88583909e-02,
#          1.46211227e-02,   7.50793442e-02,  -1.10452324e-02,
#         -1.30849397e-02,  -4.84531634e-02,   3.73451337e-02,
#         -5.01956455e-02,  -4.12854142e-02,   4.61314470e-02,
#          8.10340792e-03,  -7.80975968e-02,  -3.49188864e-01,
#         -1.84009578e-02,   5.30308392e-03,   1.19424663e-01,
#          1.06087573e-01,   5.90412924e-03,  -1.16120696e-01,
#         -3.60975452e-02,   9.16403346e-03,   2.80833840e-02,
#          5.33449911e-02,  -1.04106933e-01,   2.26132516e-02,
#         -3.69608492e-01,  -1.54414289e-02,  -6.41929284e-02,
#         -3.04659475e-02,  -3.17694881e-04,  -1.76853299e-01,
#         -8.12775046e-02,  -2.89083440e-02,  -9.21956450e-03,
#          1.44437805e-01,   6.85589248e-03,  -1.99851971e-02,
#          7.32017606e-02,  -1.29873566e-02,   1.25614688e-01,
#         -8.02779049e-02,  -1.24673612e-01,   2.47847848e-02,
#         -2.80630440e-02,  -4.03545331e-03], dtype=float32)

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
two_d_embeddings.shape
# Out:
# (400, 2)

# %%
[reverse_dictionary[i] for i in range(1, 401)][:10]
# Out:
# ['the', 'of', 'and', 'one', 'in', 'a', 'to', 'zero', 'nine', 'two']

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
two_d_embeddings.shape, len(words)
# Out:
# ((400, 2), 400)

# %% [markdown]
# ### Try using nce_loss
# Example from: https://www.tensorflow.org/tutorials/word2vec#vector-representations-of-words

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
